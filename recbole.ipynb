# %% [markdown]
# # Recboleを使ってモデルを作成してみよう

# %%
# !pip install recbole==1.1.1 ray==2.7.1 faiss-gpu==1.7.2
# Out:
# Collecting recbole==1.1.1
#   Downloading recbole-1.1.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 9.2 MB/s eta 0:00:00
# Collecting ray==2.7.1
#   Downloading ray-2.7.1-cp310-cp310-manylinux2014_x86_64.whl (62.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 MB 12.6 MB/s eta 0:00:00
# Collecting faiss-gpu==1.7.2
#   Downloading faiss_gpu-1.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (85.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 MB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from recbole==1.1.1) (2.1.0+cu118)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.10/dist-packages (from recbole==1.1.1) (1.23.5)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from recbole==1.1.1) (1.11.3)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.10/dist-packages (from recbole==1.1.1) (1.5.3)
# Requirement already satisfied: tqdm>=4.48.2 in /usr/local/lib/python3.10/dist-packages (from recbole==1.1.1) (4.66.1)
# Collecting colorlog==4.7.2 (from recbole==1.1.1)
#   Downloading colorlog-4.7.2-py2.py3-none-any.whl (10 kB)
# Collecting colorama==0.4.4 (from recbole==1.1.1)
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: scikit-learn>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from recbole==1.1.1) (1.2.2)
# Requirement already satisfied: pyyaml>=5.1.0 in /usr/local/lib/python3.10/dist-packages (from recbole==1.1.1) (6.0.1)
# Requirement already satisfied: tensorboard>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from recbole==1.1.1) (2.14.1)
# Collecting thop>=0.1.1.post2207130030 (from recbole==1.1.1)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: tabulate>=0.8.10 in /usr/local/lib/python3.10/dist-packages (from recbole==1.1.1) (0.9.0)
# Requirement already satisfied: plotly>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from recbole==1.1.1) (5.15.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from ray==2.7.1) (8.1.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from ray==2.7.1) (3.12.4)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from ray==2.7.1) (4.19.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ray==2.7.1) (1.0.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from ray==2.7.1) (23.2)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.10/dist-packages (from ray==2.7.1) (3.20.3)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.10/dist-packages (from ray==2.7.1) (1.3.1)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.10/dist-packages (from ray==2.7.1) (1.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from ray==2.7.1) (2.31.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->recbole==1.1.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->recbole==1.1.1) (2023.3.post1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.0.0->recbole==1.1.1) (8.2.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.23.2->recbole==1.1.1) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.23.2->recbole==1.1.1) (3.2.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.5.0->recbole==1.1.1) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.5.0->recbole==1.1.1) (1.59.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.5.0->recbole==1.1.1) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.5.0->recbole==1.1.1) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.5.0->recbole==1.1.1) (3.5)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.5.0->recbole==1.1.1) (67.7.2)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.5.0->recbole==1.1.1) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.5.0->recbole==1.1.1) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.5.0->recbole==1.1.1) (3.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->ray==2.7.1) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->ray==2.7.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->ray==2.7.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->ray==2.7.1) (2023.7.22)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->recbole==1.1.1) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->recbole==1.1.1) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->recbole==1.1.1) (3.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->recbole==1.1.1) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->recbole==1.1.1) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->recbole==1.1.1) (2.1.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray==2.7.1) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray==2.7.1) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray==2.7.1) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray==2.7.1) (0.10.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.5.0->recbole==1.1.1) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.5.0->recbole==1.1.1) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.5.0->recbole==1.1.1) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.5.0->recbole==1.1.1) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.5.0->recbole==1.1.1) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->recbole==1.1.1) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.5.0->recbole==1.1.1) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.5.0->recbole==1.1.1) (3.2.2)
# Installing collected packages: faiss-gpu, colorlog, colorama, thop, ray, recbole
# Successfully installed colorama-0.4.4 colorlog-4.7.2 faiss-gpu-1.7.2 ray-2.7.1 recbole-1.1.1 thop-0.1.1.post2209072238

# %%
import pandas as pd
import numpy as np
from recbole.config import Config
from recbole.quick_start import run_recbole

# %% [markdown]
# ## 基本的な使い方

# %%
# 検証するモデルをリストアップ(利用できるモデルの調べ方「2.recboleの設定.ipynb」を参照)
general_recommender_model_names = [
    'ADMMSLIM',
    'BPR',
    'CDAE',
    'ConvNCF',
    'DGCF',
    'DMF',
    'EASE',
    'ENMF',
    'FISM',
    'GCMC',
    'ItemKNN',
    'LightGCN',
    'LINE',
    'MacridVAE',
    'MultiDAE',
    'MultiVAE',
    'NAIS',
    'NCEPLRec',
    'NCL',
    'NeuMF',
    'NGCF',
    'NNCF',
    'Pop',
    'RaCT',
    'RecVAE',
    'SGL',
    'SimpleX',
    'SLIMElastic',
    'SpectralCF',
]

# %%
# 1つのデータセット、1つのモデルで実施
model_name = 'ADMMSLIM'
dataset_name = 'ml-100k'
config_dict = {
  #  "show_progress" :False,
}

result = run_recbole(model=model_name, dataset=dataset_name, config_dict=config_dict)
result
# Out:
# WARNING:root:command line args [-f /root/.local/share/jupyter/runtime/kernel-eb269d1a-b1e8-4e73-b27c-85818b290730.json] will not be used in RecBole
# Train     0: 100%|█████████████████████████| 79/79 [00:00<00:00, 90.96it/s, GPU RAM: 0.00 G/14.75 G]
# Evaluate   : 100%|███████████████████████| 472/472 [00:09<00:00, 48.34it/s, GPU RAM: 0.00 G/14.75 G]
# Evaluate   : 100%|███████████████████████| 472/472 [00:11<00:00, 42.38it/s, GPU RAM: 0.00 G/14.75 G]
# {'best_valid_score': 0.42,
#  'valid_score_bigger': True,
#  'best_valid_result': OrderedDict([('recall@10', 0.2375),
#               ('mrr@10', 0.42),
#               ('ndcg@10', 0.2569),
#               ('hit@10', 0.7709),
#               ('precision@10', 0.1769)]),
#  'test_result': OrderedDict([('recall@10', 0.2801),
#               ('mrr@10', 0.5153),
#               ('ndcg@10', 0.3245),
#               ('hit@10', 0.8197),
#               ('precision@10', 0.2188)])}

# %%
test_result = result['test_result'] # test_resultを取得
test_result['model'] = model_name # モデル名を追加
test_result.move_to_end('model', False) # モデル名を先頭に移動
print(test_result)
# Out:
# OrderedDict([('model', 'ADMMSLIM'), ('recall@10', 0.2801), ('mrr@10', 0.5153), ('ndcg@10', 0.3245), ('hit@10', 0.8197), ('precision@10', 0.2188)])

# %%
one_result_df = pd.DataFrame([test_result], columns=test_result.keys())
display(one_result_df)
# Out:
#       model  recall@10  mrr@10  ndcg@10  hit@10  precision@10
# 0  ADMMSLIM     0.2801  0.5153   0.3245  0.8197        0.2188

# %%
# 検証するモデルをリストアップ(利用できるモデルの調べ方「2.recboleの設定.ipynb」を参照)
general_recommender_model_names = [
    # 'ADMMSLIM',
    'BPR',
    # 'CDAE',
    # 'ConvNCF',
    # 'DGCF',
    # 'DMF',
    'EASE',
    # 'ENMF',
    # 'FISM',
    # 'GCMC',
    # 'ItemKNN',
    # 'LightGCN',
    # 'LINE',
    # 'MacridVAE',
    # 'MultiDAE',
    # 'MultiVAE',
    # 'NAIS',
    # 'NCEPLRec',
    # 'NCL',
    # 'NeuMF',
    # 'NGCF',
    # 'NNCF',
    'Pop',
    # 'RaCT',
    # 'RecVAE',
    # 'SGL',
    # 'SimpleX',
    # 'SLIMElastic',
    # 'SpectralCF',
]

# %%
# %%time
# ml-100kデータを利用して上記モデルでレコメンドモデルを作成して評価(利用できるデータの調べ方は"2.recboleの設定.ipynb"を参照）
# 全モデルの実行はcolabでは難しい

dataset_name = 'ml-100k'
print(dataset_name)
result_df = pd.DataFrame([])

config_dict = {
   "show_progress" :False,
}

for model_name in general_recommender_model_names:
    print(model_name)
    try:
        result = run_recbole(model=model_name, dataset=dataset_name, config_dict=config_dict)
    except Exception as e:
        print(e)
        continue
    test_result = result['test_result'] # test_resultの名前で返る
    test_result['model'] = model_name
    test_result.move_to_end('model', False) # 先頭に移動
    print(test_result)
    print("==========")
    one_result_df = pd.DataFrame([test_result], columns=test_result.keys())
    display(one_result_df)
    result_df = pd.concat([result_df, one_result_df])
    print('-----------------------------------')
display(result_df.sort_values('precision@10', ascending=False).reset_index(drop=True))
# Out:
# ml-100k
# BPR
# WARNING:root:command line args [-f /root/.local/share/jupyter/runtime/kernel-eb269d1a-b1e8-4e73-b27c-85818b290730.json] will not be used in RecBole
# OrderedDict([('model', 'BPR'), ('recall@10', 0.2466), ('mrr@10', 0.4895), ('ndcg@10', 0.2928), ('hit@10', 0.7815), ('precision@10', 0.1962)])
# ==========
#   model  recall@10  mrr@10  ndcg@10  hit@10  precision@10
# 0   BPR     0.2466  0.4895   0.2928  0.7815        0.1962
# -----------------------------------
# EASE
# WARNING:root:command line args [-f /root/.local/share/jupyter/runtime/kernel-eb269d1a-b1e8-4e73-b27c-85818b290730.json] will not be used in RecBole
# OrderedDict([('model', 'EASE'), ('recall@10', 0.2805), ('mrr@10', 0.5277), ('ndcg@10', 0.3295), ('hit@10', 0.8197), ('precision@10', 0.2206)])
# ==========
#   model  recall@10  mrr@10  ndcg@10  hit@10  precision@10
# 0  EASE     0.2805  0.5277   0.3295  0.8197        0.2206
# -----------------------------------
# Pop
# WARNING:root:command line args [-f /root/.local/share/jupyter/runtime/kernel-eb269d1a-b1e8-4e73-b27c-85818b290730.json] will not be used in RecBole
# OrderedDict([('model', 'Pop'), ('recall@10', 0.085), ('mrr@10', 0.1979), ('ndcg@10', 0.1032), ('hit@10', 0.4719), ('precision@10', 0.0828)])
# ==========
#   model  recall@10  mrr@10  ndcg@10  hit@10  precision@10
# 0   Pop      0.085  0.1979   0.1032  0.4719        0.0828
# -----------------------------------
#   model  recall@10  mrr@10  ndcg@10  hit@10  precision@10
# 0  EASE     0.2805  0.5277   0.3295  0.8197        0.2206
# 1   BPR     0.2466  0.4895   0.2928  0.7815        0.1962
# 2   Pop     0.0850  0.1979   0.1032  0.4719        0.0828
# CPU times: user 41.1 s, sys: 779 ms, total: 41.9 s
# Wall time: 45.4 s
